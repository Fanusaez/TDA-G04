# %% [markdown]
# # TP1 - TDA 1

# %%
from algoritmo import obtener_tiempo_minimo
from parseo_pruebas import obtener_tiempos_de_archivo

# %%
import time
import random
import matplotlib.pyplot as plt

# %% [markdown]
# ## Realizado con los textos de la catedra

# %%
tiempos = []
tamanio_de_datos = [3, 10, 100, 1000, 10000]

# %% [markdown]
# Tiempo con 3 elementos

# %%
s, a = obtener_tiempos_de_archivo('./textos_pruebas/3_elem.txt')
inicio = time.time()
obtener_tiempo_minimo(s, a)
fin = time.time()

tiempo_ms = (fin - inicio) * 1000  # Convertir a milisegundos
tiempos.append(tiempo_ms)
print(tiempo_ms)
# Out:
# 0.09608268737792969

# %% [markdown]
# Tiempo con 10 elementos

# %%
s, a = obtener_tiempos_de_archivo('./textos_pruebas/10_elem.txt')
inicio = time.time()
obtener_tiempo_minimo(s, a)
fin = time.time()

tiempo_ms = (fin - inicio) * 1000  # Convertir a milisegundos
tiempos.append(tiempo_ms)
print(tiempo_ms)
# Out:
# 0.056743621826171875

# %% [markdown]
# Tiempo con 100 elementos

# %%
s, a = obtener_tiempos_de_archivo('./textos_pruebas/100_elem.txt')
inicio = time.time()
obtener_tiempo_minimo(s, a)
fin = time.time()

tiempo_ms = (fin - inicio) * 1000  # Convertir a milisegundos
tiempos.append(tiempo_ms)
print(tiempo_ms)
# Out:
# 0.08749961853027344

# %% [markdown]
# Tiempo con 1000 elementos

# %%
s = [random.uniform(1, 100) for _ in range(1000)]
a = [random.uniform(1, 100) for _ in range(1000)]
inicio = time.time()
obtener_tiempo_minimo(s, a)
fin = time.time()

tiempo_ms = (fin - inicio) * 1000  # Convertir a milisegundos
tiempos.append(tiempo_ms)
print(tiempo_ms)
# Out:
# 0.637054443359375

# %% [markdown]
# Tiempo con 10000 elementos

# %%
s, a = obtener_tiempos_de_archivo('./textos_pruebas/10000_elem.txt')
inicio = time.time()
obtener_tiempo_minimo(s, a)
fin = time.time()

tiempo_ms = (fin - inicio) * 1000  # Convertir a milisegundos
tiempos.append(tiempo_ms)
print(tiempo_ms)
# Out:
# 8.24594497680664

# %%
plt.plot(tamanio_de_datos, tiempos, marker='o')
plt.xlabel('Tamaño de datos')
plt.ylabel('Tiempo de ejecución (ms)')
plt.title('Rendimiento del algoritmo')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Grafico realizado con elementos al azar con random

# %%
tamanos_datos = [10, 100, 1000, 10000, 100000]
tiempos_ejecucion = []

for n in tamanos_datos:
    tiempos_ejecucion_temp = []  # Lista temporal para guardar tiempos de ejecucion de múltiples ejecuciones
    for _ in range(50):  # Ejecutar 50 veces para calcular un promedio
        
        # Generar listas aleatorias de s y a con n elementos
        s = [random.uniform(1, 100) for _ in range(n)]
        a = [random.uniform(1, 100) for _ in range(n)]
        
        #Medimos el tiempo de ejecucion
        start_time = time.time()
        obtener_tiempo_minimo(s, a)
        end_time = time.time()
        
        tiempo_ms = (end_time - start_time) * 1000  # Convertir a milisegundos
        tiempos_ejecucion_temp.append(tiempo_ms)
        
    # Calcular el promedio de las ejecuciones y agregarlo a la lista final
    tiempo_promedio_ms = sum(tiempos_ejecucion_temp) / len(tiempos_ejecucion_temp)
    tiempos_ejecucion.append(tiempo_promedio_ms)

#Graficamos
plt.figure(figsize=(10, 6))
plt.plot(tamanos_datos, tiempos_ejecucion, marker='o')
plt.xlabel('Tamaño de datos')
plt.ylabel('Tiempo de ejecución (ms)')
plt.title('Rendimiento del algoritmo')
plt.grid(True)
plt.show()

# %%
print(tamanos_datos)
print(tiempos_ejecucion)
# Out:
# [10, 100, 1000, 5000, 10000]
# [0.01723766326904297, 0.0536036491394043, 0.3757452964782715, 1.9994711875915527, 3.737971782684326]
