# %%
from parsear_archivo import obtener_energia_demandada_y_disponible, obtener_resultado
from tp2 import optimo_entrenamientos, obtener_lista_entrenamientos

# %%
import time
import random
import matplotlib.pyplot as plt

# %% [markdown]
# # Graficos con series provistas por la catedra

# %%
tiempos = []
tamanio_de_datos = [3, 10, 50, 100, 500, 1000, 5000]
archivos = ['./textos_pruebas/3.txt', './textos_pruebas/10.txt', './textos_pruebas/50.txt', './textos_pruebas/100.txt', './textos_pruebas/500.txt', './textos_pruebas/1000.txt', './textos_pruebas/5000.txt']

for archivo in archivos:
    tiempos_ejecucion_temp = []  # Lista temporal para guardar tiempos de ejecucion de múltiples ejecuciones
    
    for _ in range(5):  # Ejecutar 5 veces para calcular un promedio
        
        e, s = obtener_energia_demandada_y_disponible(archivo)
        
        #Medimos el tiempo de ejecucion
        start_time = time.time()
        optimo_entrenamientos(e, s)
        end_time = time.time()
        
        tiempo_ms = (end_time - start_time) * 1000  # Convertir a milisegundos
        tiempos_ejecucion_temp.append(tiempo_ms)
        
    # Calcular el promedio de las ejecuciones y agregarlo a la lista final
    tiempo_promedio_ms = sum(tiempos_ejecucion_temp) / len(tiempos_ejecucion_temp)
    tiempos.append(tiempo_promedio_ms)

#Graficamos
plt.plot(tamanio_de_datos, tiempos, marker='o')
plt.xscale("log")
plt.xlabel('Tamaño de datos')
plt.ylabel('Tiempo de ejecución (ms)')
plt.title('Rendimiento del algoritmo')
plt.grid(True)
plt.show()

# %% [markdown]
# # Graficos con series al azar

# %% [markdown]
# ### Grafico Realizado con elementos al azar, serie de 1000 a 10.000 en saltos de 1000

# %%
tamanos_datos = list(range(1000, 15000, 1000))
tiempos_ejecucion = []

for n in tamanos_datos:
    tiempos_ejecucion_temp = []  # Lista temporal para guardar tiempos de ejecucion de múltiples ejecuciones
    for _ in range(5):  # Ejecutar 5 veces para calcular un promedio
        
        # Generar listas aleatorias de s y a con n elementos
        s = [random.uniform(1, 100) for _ in range(n)]
        s_descendente = sorted(s, reverse=True)
        e = [random.uniform(1, 100) for _ in range(n)]
        
        #Medimos el tiempo de ejecucion
        start_time = time.time()
        optimo_entrenamientos(e, s_descendente)
        end_time = time.time()
        
        tiempo_ms = (end_time - start_time) * 1000  # Convertir a milisegundos
        tiempos_ejecucion_temp.append(tiempo_ms)
        
    # Calcular el promedio de las ejecuciones y agregarlo a la lista final
    tiempo_promedio_ms = sum(tiempos_ejecucion_temp) / len(tiempos_ejecucion_temp)
    tiempos_ejecucion.append(tiempo_promedio_ms)

#Graficamos
plt.figure(figsize=(10, 6))
plt.plot(tamanos_datos, tiempos_ejecucion, marker='o')
plt.xlabel('Tamaño de datos')
plt.ylabel('Tiempo de ejecución (ms)')
plt.title('Rendimiento del algoritmo')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Grafico Realizado con elementos al azar, serie de 10 a 100.000 exponencialmente

# %%
tamanos_datos = [10, 100, 1000, 10000]
tiempos_ejecucion = []

for n in tamanos_datos:
    tiempos_ejecucion_temp = []  # Lista temporal para guardar tiempos de ejecucion de múltiples ejecuciones
    for _ in range(1):  # Ejecutar 5 veces para calcular un promedio
        
        # Generar listas aleatorias de s y a con n elementos
        s = [random.uniform(1, 100) for _ in range(n)]
        s_descendente = sorted(s, reverse=True)
        e = [random.uniform(1, 100) for _ in range(n)]
        
        #Medimos el tiempo de ejecucion
        start_time = time.time()
        optimo_entrenamientos(e, s_descendente)
        end_time = time.time()
        
        tiempo_ms = (end_time - start_time) * 1000  # Convertir a milisegundos
        tiempos_ejecucion_temp.append(tiempo_ms)
        
    # Calcular el promedio de las ejecuciones y agregarlo a la lista final
    tiempo_promedio_ms = sum(tiempos_ejecucion_temp) / len(tiempos_ejecucion_temp)
    tiempos_ejecucion.append(tiempo_promedio_ms)

#Graficamos
plt.figure(figsize=(10, 6))
plt.plot(tamanos_datos, tiempos_ejecucion, marker='o')
plt.xlabel('Tamaño de datos')
plt.ylabel('Tiempo de ejecución (ms)')
plt.title('Rendimiento del algoritmo')
plt.grid(True)
plt.show()
